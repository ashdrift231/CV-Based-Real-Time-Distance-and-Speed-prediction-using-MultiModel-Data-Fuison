# %%
import os
import multiprocessing

# Get the number of available CPU cores
num_cores = multiprocessing.cpu_count()

print(num_cores)

# Set the environment variable to use all CPU cores
os.environ["OMP_NUM_THREADS"] = str(num_cores)
# Out:
# 4

# %%
import glob
from IPython.display import display, Image

# !pip install -U ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.5 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5597.6/8062.4 GB disk)

# %%
#roboflow dataset download yolo2
'''!pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="MQrPTFMxjsrD8qSoagQE")
project = rf.workspace("vault-e2msr").project("yolot-b1gmy")
version = project.version(1)
dataset = version.download("yolov8")'''

# %%
#roboflow dataset download yolo2.1
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="eyl6ldewtf05KH4F7A7A")
project = rf.workspace("spear").project("yolot2")
version = project.version(1)
dataset = version.download("yolov8")

# %%
# !conda install -y gdown
#!gdown --id 1Zs5ybBwl_r_b0_IM9sjV5ckN1T-ek3cX #640model checkpoint (tune1.1) last.pt
# !gdown --id 1yb5DmgXALSo7rEgX90BdYL9u1J30tYL5 #best.pt
#!gdown --id 15EbSOR5sjmOkW-ENZhfbE896EZyZj4Rt #yolo1.1.zip
#!unzip yolo1.1.zip
#!rm -r yolo1.1.zip

# %%
import yaml

# Define the configuration parameters
config = {
    "train": "/kaggle/working/yoloT2-1/train/images",
    "test": "/kaggle/working/yoloT2-1/test/images",
    "val": "/kaggle/working/yoloT2-1/valid/images",
    "nc": 9,  # Number of classes
    "names": [
        "barrier",
        "bicycle",
        "bus",
        "car",
        "construction vehicle",
        "motorcycle",
        "pedestrian",
        "trailer",
        "truck"
    ],  # List of class names

    "roboflow": {
        "license": "CC BY 4.0",
        "project": "yolot-b1gmy",
        "url": "https://universe.roboflow.com/vault-e2msr/yolot-b1gmy/dataset/1",
        "version": 1,
        "workspace": "vault-e2msr"
    },
    
    "name": "FlashPredict"  # Name of the experiment
}

# Save the configuration to a YAML file
with open("/kaggle/working/yoloT2-1/data.yaml", "w") as yaml_file:
    yaml.dump(config, yaml_file, default_flow_style=False)

# %%
# !yolo task=detect mode=train model=/kaggle/working/best.pt data=/kaggle/working/yoloT2-1/data.yaml epochs=100 imgsz=640 batch=36

# %%
# !yolo task=detect mode=predict model=/kaggle/working/best.pt conf=0.25 source=/kaggle/working/yoloT2-1/test/images

# %%
Image(filename='/kaggle/working/runs/detect/predict/4083_jpg.rf.8d6b19936435b106c433a648d85576cc.jpg',width=600)

# %%
for image_path in glob.glob('/kaggle/working/runs/detect/predict/*.jpg')[:15]:
    display(Image(filename=image_path, width=600))
    print("\n")

# %%
'''import yaml

# Define the configuration parameters
config = {
    "train": "/kaggle/working/yoloT-1/train/images",
    "test": "/kaggle/working/yoloT-1/test/images",
    "val": "/kaggle/working/yoloT-1/val/images",
    "nc": 9,  # Number of classes
    "names": [
        "truck",
        "pedestrian",
        "bus",
        "car",
        "barrier",
        "const.vehicle",
        "trailer",
        "motorcycle",
        "bicycle"
    ],  # List of class names

    "name": "FlashPredict"  # Name of the experiment
}

# Save the configuration to a YAML file
with open("/kaggle/working/yolo1.1/FlashPredict.yaml", "w") as yaml_file:
    yaml.dump(config, yaml_file, default_flow_style=False)'''
